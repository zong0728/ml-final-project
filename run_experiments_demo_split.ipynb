# %%
# === Colab bootstrap: mount drive, clone/pull repo, link dataset ===
# Run this cell once after every Colab reconnect.
import os
from google.colab import drive, userdata

DATASET_DRIVE_PATH = '/content/drive/MyDrive/ml-final-project-data'
REPO_DIR = '/content/ml-final-project'

# 1. Mount Drive
if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')

# 2. Clone or pull repo
token = userdata.get('COLAB_ML_FINAL_PROJECT')
if not os.path.exists(REPO_DIR):
    os.chdir('/content')
    # !git clone https://{token}@github.com/zong0728/ml-final-project.git
else:
    os.chdir(REPO_DIR)
    # !git pull

os.chdir(REPO_DIR)

# 3. Symlink dataset from Drive
# !ln -sfn "{DATASET_DRIVE_PATH}" "{REPO_DIR}/dataset"

# 4. Git identity (only needed if pushing from Colab)
# !git config user.email "shengzhg@andrew.cmu.edu"
# !git config user.name "Shengzhong Guan"

# 5. Embed token in remote so future git pull/push works without prompting
# !git remote set-url origin https://{token}@github.com/zong0728/ml-final-project.git

print("✓ Repo ready at:", os.getcwd())
# !ls -la dataset/ 2>&1 | head -5

# %% [markdown]
# # Power Outage Forecasting — Model Comparison (DEMO-SPLIT VARIANT)
#
# **Identical to `run_experiments.ipynb` except for ONE change**: the validation split.
#
# | | This notebook | `run_experiments.ipynb` (primary) |
# |---|---|---|
# | Val split | Last **20%** of training = 433h (demo convention) | Last **48h** of training |
# | Zero baseline 24h | ~100.31 | 43.61 |
# | Zero baseline 48h | ~75.36 | 70.49 |
# | Results dir | `results_demo_split/` | `results/` |
#
# **Why this notebook exists**: teammates who followed the starter-kit demo (with `VALIDATION_SPLIT = 0.2`) will report numbers under a different baseline. Running with demo's split lets us compare apples-to-apples against their models.
#
# Everything else — models, hyperparameters, Part II policy — is unchanged. See `run_experiments.ipynb` for full pipeline documentation.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -q xarray netCDF4 xgboost lightgbm catboost statsmodels

# %% [markdown]
# ## 2. Locate project root + put `src/` on the path
#
# This cell auto-detects your setup. Expected layouts:
# * **Local**: notebook sits at `<project>/run_experiments.ipynb` — nothing to do.
# * **Colab (folder upload)**: upload the whole project folder to `/content/` (drag&drop or `!unzip`).
# * **Colab (Drive mount)**: put the folder somewhere in `MyDrive`; this cell mounts Drive and searches for it.

# %%
import os, sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

def find_project_root() -> Path:
    candidates = [Path.cwd()]
    if IN_COLAB:
        # Common upload locations
        candidates += [
            Path("/content/ml-final-project"),
            Path("/content/MLPS_Project"),
            Path("/content"),
        ]
        # Drive (mount lazily only if needed)
        from google.colab import drive
        if not Path("/content/drive").exists():
            drive.mount("/content/drive")
        for p in [
            Path("/content/drive/MyDrive/ml-final-project"),
            Path("/content/drive/MyDrive/MLPS_Project"),
        ]:
            candidates.append(p)
    for c in candidates:
        if (c / "dataset" / "data" / "train.nc").exists() and (c / "src").exists():
            return c.resolve()
    raise FileNotFoundError(
        "Could not locate project folder. Upload the full folder and make sure "
        "`dataset/data/train.nc` and `src/` both exist inside it."
    )

PROJECT_ROOT = find_project_root()
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print(f"Project root: {PROJECT_ROOT}")
print(f"CUDA available: ", end="")
import torch
print(torch.cuda.is_available(), "-", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Project root: /content/drive/MyDrive/ml-final-project
# CUDA available: True - NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 3. Experiment configuration
#
# Tune these if you want to restrict the sweep (e.g. for a quick smoke test).

# %%
from src import config

# ========== DEMO-SPLIT OVERRIDE (the ONLY meaningful difference) ==========
# Switch VAL_HOURS from 48 -> last 20% of training (matches demo notebook).
# IMPORTANT: this override must happen BEFORE importing src.runner, because
# runner.py computes VAL_PRED_DIR at module-load time.
import xarray as xr
_ds_tmp = xr.open_dataset(config.TRAIN_PATH)
_T = len(_ds_tmp.timestamp)
_ds_tmp.close()

config.VAL_HOURS = _T - int(_T * 0.8)   # 433h for T=2161 (matches demo's split_idx=int(T*0.8)=1728)
config.RESULTS_DIR      = config.PROJECT_ROOT / "results_demo_split"
config.CHECKPOINT_DIR   = config.RESULTS_DIR / "checkpoints"
config.FIGURES_DIR      = config.RESULTS_DIR / "figures"
config.SUBMISSIONS_DIR  = config.RESULTS_DIR / "submissions"
config.RUNS_CSV         = config.RESULTS_DIR / "experiment_runs.csv"
for d in (config.RESULTS_DIR, config.CHECKPOINT_DIR, config.FIGURES_DIR, config.SUBMISSIONS_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"DEMO-SPLIT override active:")
print(f"  VAL_HOURS    = {config.VAL_HOURS}  ({config.VAL_HOURS/_T*100:.0f}% of training)")
print(f"  RESULTS_DIR  = {config.RESULTS_DIR}")
print(f"  RUNS_CSV     = {config.RUNS_CSV}")
# ==========================================================================

from src.runner import run_all
from src.registry import MODEL_REGISTRY
from src.training import summarize_runs

# ---- Sweep controls ----
SEEDS    = [42, 43, 44]   # 3 seeds for stochastic models; deterministic models run once
HORIZONS = [24, 48]
MODELS_TO_RUN = None      # None = all registered. Or pass a list: ["lstm", "dlinear"]

# Show what will be run
print(f"\nRegistered models ({len(MODEL_REGISTRY)}):")
for name, info in MODEL_REGISTRY.items():
    flag = "stoch" if info.stochastic else "det  "
    print(f"  [{info.tier:9s}] [{flag}]  {name:16s}  {info.description}")
# Out:
# DEMO-SPLIT override active:
#   VAL_HOURS    = 433  (20% of training)
#   RESULTS_DIR  = /content/drive/MyDrive/ml-final-project/results_demo_split
#   RUNS_CSV     = /content/drive/MyDrive/ml-final-project/results_demo_split/experiment_runs.csv
#
# Registered models (20):
#   [baseline ] [det  ]  zero              Predict zero for every county-hour.
#   [baseline ] [det  ]  persistence       Repeat the last observed value for the whole horizon.
#   [baseline ] [det  ]  seasonal_naive_24  ŷ[t+h] = y[t+h-24] — repeat yesterday's same hour.
#   [baseline ] [det  ]  seasonal_naive_168  ŷ[t+h] = y[t+h-168] — repeat same hour last week.
#   [baseline ] [det  ]  historical_mean   Per-(county, hour-of-day, day-of-week) historical mean.
#   [classical] [det  ]  linreg_lag        LinearRegression on lag/rolling/weather features (log1p target).
#   [classical] [det  ]  ridge_lag         Ridge(α=1.0) on lag/rolling/weather features (log1p target).
#   [classical] [stoch]  xgboost           XGBoost regressor on lag features (log1p target).
#   [classical] [stoch]  lightgbm          LightGBM regressor on lag features (log1p target).
#   [classical] [det  ]  sarimax           Per-county SARIMAX(1,0,1) — classical time-series baseline.
#   [neural   ] [stoch]  mlp               Flat MLP over flattened (seq_len × D) window.
#   [neural   ] [stoch]  lstm              LSTM encoder + linear head (demo's model, deeper).
#   [neural   ] [stoch]  gru               GRU encoder + linear head.
#   [neural   ] [stoch]  bilstm            Bidirectional LSTM — looks both ways within the history window.
#   [neural   ] [stoch]  tcn               Dilated causal 1D-CNN (TCN, Bai et al. 2018).
#   [neural   ] [stoch]  transformer       Vanilla Transformer encoder + last-token head.
#   [sota     ] [stoch]  nlinear           NLinear (Zeng 2022): last-value normalize + linear.
#   [sota     ] [stoch]  dlinear           DLinear (Zeng 2022): trend/seasonal decomposition + two linears.
#   [sota     ] [stoch]  patchtst          PatchTST (Nie 2023): channel-independent transformer over patches.
#   [sota     ] [stoch]  itransformer      iTransformer (Liu 2024): variates-as-tokens attention.

# %% [markdown]
# ## 4. Dry run — preview the schedule

# %%
_ = run_all(
    model_names=MODELS_TO_RUN,
    horizons=HORIZONS,
    seeds=SEEDS,
    dry_run=True,
)
# Out:
# [Runner] Scheduled 88 runs across 20 models, seeds=[42, 43, 44], horizons=[24, 48]
#   DET    model=zero              seed=42  horizon=24
#   DET    model=zero              seed=42  horizon=48
#   DET    model=persistence       seed=42  horizon=24
#   DET    model=persistence       seed=42  horizon=48
#   DET    model=seasonal_naive_24  seed=42  horizon=24
#   DET    model=seasonal_naive_24  seed=42  horizon=48
#   DET    model=seasonal_naive_168  seed=42  horizon=24
#   DET    model=seasonal_naive_168  seed=42  horizon=48
#   DET    model=historical_mean   seed=42  horizon=24
#   DET    model=historical_mean   seed=42  horizon=48
#   DET    model=linreg_lag        seed=42  horizon=24
#   DET    model=linreg_lag        seed=42  horizon=48
#   DET    model=ridge_lag         seed=42  horizon=24
#   DET    model=ridge_lag         seed=42  horizon=48
#   STOCH  model=xgboost           seed=42  horizon=24
#   STOCH  model=xgboost           seed=42  horizon=48
#   STOCH  model=xgboost           seed=43  horizon=24
#   STOCH  model=xgboost           seed=43  horizon=48
#   STOCH  model=xgboost           seed=44  horizon=24
#   STOCH  model=xgboost           seed=44  horizon=48
#   STOCH  model=lightgbm          seed=42  horizon=24
#   STOCH  model=lightgbm          seed=42  horizon=48
#   STOCH  model=lightgbm          seed=43  horizon=24
#   STOCH  model=lightgbm          seed=43  horizon=48
#   STOCH  model=lightgbm          seed=44  horizon=24
#   STOCH  model=lightgbm          seed=44  horizon=48
#   DET    model=sarimax           seed=42  horizon=24
#   DET    model=sarimax           seed=42  horizon=48
#   STOCH  model=mlp               seed=42  horizon=24
#   STOCH  model=mlp               seed=42  horizon=48
#   STOCH  model=mlp               seed=43  horizon=24
#   STOCH  model=mlp               seed=43  horizon=48
#   STOCH  model=mlp               seed=44  horizon=24
#   STOCH  model=mlp               seed=44  horizon=48
#   STOCH  model=lstm              seed=42  horizon=24
#   STOCH  model=lstm              seed=42  horizon=48
#   STOCH  model=lstm              seed=43  horizon=24
#   STOCH  model=lstm              seed=43  horizon=48
#   STOCH  model=lstm              seed=44  horizon=24
#   STOCH  model=lstm              seed=44  horizon=48
#   STOCH  model=gru               seed=42  horizon=24
#   STOCH  model=gru               seed=42  horizon=48
#   STOCH  model=gru               seed=43  horizon=24
#   STOCH  model=gru               seed=43  horizon=48
#   STOCH  model=gru               seed=44  horizon=24
#   STOCH  model=gru               seed=44  horizon=48
#   STOCH  model=bilstm            seed=42  horizon=24
#   STOCH  model=bilstm            seed=42  horizon=48
#   STOCH  model=bilstm            seed=43  horizon=24
#   STOCH  model=bilstm            seed=43  horizon=48
#   STOCH  model=bilstm            seed=44  horizon=24
#   STOCH  model=bilstm            seed=44  horizon=48
#   STOCH  model=tcn               seed=42  horizon=24
#   STOCH  model=tcn               seed=42  horizon=48
#   STOCH  model=tcn               seed=43  horizon=24
#   STOCH  model=tcn               seed=43  horizon=48
#   STOCH  model=tcn               seed=44  horizon=24
#   STOCH  model=tcn               seed=44  horizon=48
#   STOCH  model=transformer       seed=42  horizon=24
#   STOCH  model=transformer       seed=42  horizon=48
#   STOCH  model=transformer       seed=43  horizon=24
#   STOCH  model=transformer       seed=43  horizon=48
#   STOCH  model=transformer       seed=44  horizon=24
#   STOCH  model=transformer       seed=44  horizon=48
#   STOCH  model=nlinear           seed=42  horizon=24
#   STOCH  model=nlinear           seed=42  horizon=48
#   STOCH  model=nlinear           seed=43  horizon=24
#   STOCH  model=nlinear           seed=43  horizon=48
#   STOCH  model=nlinear           seed=44  horizon=24
#   STOCH  model=nlinear           seed=44  horizon=48
#   STOCH  model=dlinear           seed=42  horizon=24
#   STOCH  model=dlinear           seed=42  horizon=48
#   STOCH  model=dlinear           seed=43  horizon=24
#   STOCH  model=dlinear           seed=43  horizon=48
#   STOCH  model=dlinear           seed=44  horizon=24
#   STOCH  model=dlinear           seed=44  horizon=48
#   STOCH  model=patchtst          seed=42  horizon=24
#   STOCH  model=patchtst          seed=42  horizon=48
#   STOCH  model=patchtst          seed=43  horizon=24
#   STOCH  model=patchtst          seed=43  horizon=48
#   STOCH  model=patchtst          seed=44  horizon=24
#   STOCH  model=patchtst          seed=44  horizon=48
#   STOCH  model=itransformer      seed=42  horizon=24
#   STOCH  model=itransformer      seed=42  horizon=48
#   STOCH  model=itransformer      seed=43  horizon=24
#   STOCH  model=itransformer      seed=43  horizon=48
#   STOCH  model=itransformer      seed=44  horizon=24
#   STOCH  model=itransformer      seed=44  horizon=48

# %% [markdown]
# ## 5. Run everything (the overnight cell)
#
# Models run fast-to-slow-ish; each is logged to `results/experiment_runs.csv` as soon as it finishes. Safe to interrupt — just rerun and it resumes.

# %%
summary = run_all(
    model_names=MODELS_TO_RUN,
    horizons=HORIZONS,
    seeds=SEEDS,
    skip_on_error=True,   # don't let one bad model kill the whole night
)
# Out:
# [Runner] Scheduled 88 runs across 20 models, seeds=[42, 43, 44], horizons=[24, 48]
#
# [  1/88] model=zero  seed=42  horizon=24h
# -----------------------------------------
#   val_rmse=100.3053  time=0.0s  total=0.0min
#
# [  2/88] model=zero  seed=42  horizon=48h
# -----------------------------------------
#   val_rmse=75.3561  time=0.0s  total=0.0min
#
# [  3/88] model=persistence  seed=42  horizon=24h
# ------------------------------------------------
#   val_rmse=129.1698  time=0.0s  total=0.0min
#
# [  4/88] model=persistence  seed=42  horizon=48h
# ------------------------------------------------
#   val_rmse=117.7581  time=0.0s  total=0.0min
#
# [  5/88] model=seasonal_naive_24  seed=42  horizon=24h
# ------------------------------------------------------
#   val_rmse=145.2781  time=0.0s  total=0.0min
#
# [  6/88] model=seasonal_naive_24  seed=42  horizon=48h
# ------------------------------------------------------
#   val_rmse=123.5066  time=0.0s  total=0.0min
#
# [  7/88] model=seasonal_naive_168  seed=42  horizon=24h
# -------------------------------------------------------
#   val_rmse=111.2700  time=0.0s  total=0.0min
#
# [  8/88] model=seasonal_naive_168  seed=42  horizon=48h
# -------------------------------------------------------
#   val_rmse=89.8130  time=0.0s  total=0.0min
#
# [  9/88] model=historical_mean  seed=42  horizon=24h
# ----------------------------------------------------
#   val_rmse=104.2867  time=0.0s  total=0.0min
#
# [ 10/88] model=historical_mean  seed=42  horizon=48h
# ----------------------------------------------------
#   val_rmse=87.7917  time=0.0s  total=0.0min
#
# [ 11/88] model=linreg_lag  seed=42  horizon=24h
# -----------------------------------------------
#   val_rmse=100.3184  time=4.6s  total=0.1min
#
# [ 12/88] model=linreg_lag  seed=42  horizon=48h
# -----------------------------------------------
#   val_rmse=75.3764  time=7.1s  total=0.2min
#
# [ 13/88] model=ridge_lag  seed=42  horizon=24h
# ----------------------------------------------
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.65359e-16): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#   val_rmse=99.4535  time=1.1s  total=0.2min
#
# [ 14/88] model=ridge_lag  seed=42  horizon=48h
# ----------------------------------------------
#   val_rmse=74.7819  time=16.2s  total=0.5min
#
# [ 15/88] model=xgboost  seed=42  horizon=24h
# --------------------------------------------
#   val_rmse=92.7525  time=5.6s  total=0.6min
#
# [ 16/88] model=xgboost  seed=42  horizon=48h
# --------------------------------------------
#   val_rmse=68.8769  time=8.2s  total=0.7min
#
# [ 17/88] model=xgboost  seed=43  horizon=24h
# --------------------------------------------
#   val_rmse=91.8847  time=4.7s  total=0.8min
#
# [ 18/88] model=xgboost  seed=43  horizon=48h
# --------------------------------------------
#   val_rmse=68.7039  time=8.1s  total=1.0min
#
# [ 19/88] model=xgboost  seed=44  horizon=24h
# --------------------------------------------
#   val_rmse=91.1032  time=4.7s  total=1.0min
#
# [ 20/88] model=xgboost  seed=44  horizon=48h
# --------------------------------------------
#   val_rmse=68.1889  time=8.1s  total=1.2min
#
# [ 21/88] model=lightgbm  seed=42  horizon=24h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=90.8265  time=38.4s  total=1.8min
#
# [ 22/88] model=lightgbm  seed=42  horizon=48h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=69.1002  time=64.1s  total=2.9min
#
# [ 23/88] model=lightgbm  seed=43  horizon=24h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=92.0402  time=34.7s  total=3.5min
#
# [ 24/88] model=lightgbm  seed=43  horizon=48h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=69.1958  time=60.0s  total=4.5min
#
# [ 25/88] model=lightgbm  seed=44  horizon=24h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=90.1589  time=33.7s  total=5.0min
#
# [ 26/88] model=lightgbm  seed=44  horizon=48h
# ---------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#   val_rmse=68.4028  time=58.7s  total=6.0min
#
# [ 27/88] model=sarimax  seed=42  horizon=24h
# --------------------------------------------
#   val_rmse=89.7449  time=8.6s  total=6.1min
#
# [ 28/88] model=sarimax  seed=42  horizon=48h
# --------------------------------------------
#   val_rmse=68.3606  time=8.8s  total=6.3min
#
# [ 29/88] model=mlp  seed=42  horizon=24h
# ----------------------------------------
#   val_rmse=104.0018  time=25.7s  total=6.7min
#
# [ 30/88] model=mlp  seed=42  horizon=48h
# ----------------------------------------
#   val_rmse=78.0852  time=20.8s  total=7.1min
#
# [ 31/88] model=mlp  seed=43  horizon=24h
# ----------------------------------------
#   val_rmse=105.3047  time=21.0s  total=7.4min
#
# [ 32/88] model=mlp  seed=43  horizon=48h
# ----------------------------------------
#   val_rmse=76.8116  time=32.9s  total=8.0min
#
# [ 33/88] model=mlp  seed=44  horizon=24h
# ----------------------------------------
#   val_rmse=96.2280  time=23.4s  total=8.4min
#
# [ 34/88] model=mlp  seed=44  horizon=48h
# ----------------------------------------
#   val_rmse=79.4858  time=18.6s  total=8.7min
#
# [ 35/88] model=lstm  seed=42  horizon=24h
# -----------------------------------------
#   val_rmse=89.1137  time=25.6s  total=9.1min
#
# [ 36/88] model=lstm  seed=42  horizon=48h
# -----------------------------------------
#   val_rmse=75.6755  time=59.1s  total=10.1min
#
# [ 37/88] model=lstm  seed=43  horizon=24h
# -----------------------------------------
#   val_rmse=99.5453  time=27.6s  total=10.5min
#
# [ 38/88] model=lstm  seed=43  horizon=48h
# -----------------------------------------
#   val_rmse=73.8468  time=59.1s  total=11.5min
#
# [ 39/88] model=lstm  seed=44  horizon=24h
# -----------------------------------------
#   val_rmse=100.6063  time=36.7s  total=12.1min
#
# [ 40/88] model=lstm  seed=44  horizon=48h
# -----------------------------------------
#   val_rmse=72.9823  time=53.3s  total=13.0min
#
# [ 41/88] model=gru  seed=42  horizon=24h
# ----------------------------------------
#   val_rmse=103.2478  time=44.6s  total=13.8min
#
# [ 42/88] model=gru  seed=42  horizon=48h
# ----------------------------------------
#   val_rmse=74.9712  time=32.6s  total=14.3min
#
# [ 43/88] model=gru  seed=43  horizon=24h
# ----------------------------------------
#   val_rmse=103.1465  time=27.5s  total=14.8min
#
# [ 44/88] model=gru  seed=43  horizon=48h
# ----------------------------------------
#   val_rmse=84.3832  time=35.3s  total=15.4min
#
# [ 45/88] model=gru  seed=44  horizon=24h
# ----------------------------------------
#   val_rmse=100.3138  time=30.2s  total=15.9min
#
# [ 46/88] model=gru  seed=44  horizon=48h
# ----------------------------------------
#   val_rmse=73.7969  time=35.4s  total=16.5min
#
# [ 47/88] model=bilstm  seed=42  horizon=24h
# -------------------------------------------
#   val_rmse=96.2548  time=35.3s  total=17.0min
#
# [ 48/88] model=bilstm  seed=42  horizon=48h
# -------------------------------------------
#   val_rmse=74.5542  time=33.9s  total=17.6min
#
# [ 49/88] model=bilstm  seed=43  horizon=24h
# -------------------------------------------
#   val_rmse=98.2406  time=63.4s  total=18.7min
#
# [ 50/88] model=bilstm  seed=43  horizon=48h
# -------------------------------------------
#   val_rmse=67.3766  time=38.2s  total=19.3min
#
# [ 51/88] model=bilstm  seed=44  horizon=24h
# -------------------------------------------
#   val_rmse=97.5297  time=26.0s  total=19.7min
#
# [ 52/88] model=bilstm  seed=44  horizon=48h
# -------------------------------------------
#   val_rmse=83.1926  time=30.9s  total=20.3min
#
# [ 53/88] model=tcn  seed=42  horizon=24h
# ----------------------------------------
#   val_rmse=101.2549  time=57.5s  total=21.2min
#
# [ 54/88] model=tcn  seed=42  horizon=48h
# ----------------------------------------
#   val_rmse=76.4594  time=100.3s  total=22.9min
#
# [ 55/88] model=tcn  seed=43  horizon=24h
# ----------------------------------------
#   val_rmse=103.2285  time=45.8s  total=23.7min
#
# [ 56/88] model=tcn  seed=43  horizon=48h
# ----------------------------------------
#   val_rmse=72.0846  time=56.7s  total=24.6min
#
# [ 57/88] model=tcn  seed=44  horizon=24h
# ----------------------------------------
#   val_rmse=100.6289  time=87.3s  total=26.1min
#
# [ 58/88] model=tcn  seed=44  horizon=48h
# ----------------------------------------
#   val_rmse=82.2589  time=56.7s  total=27.0min
#
# [ 59/88] model=transformer  seed=42  horizon=24h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=95.9033  time=113.8s  total=28.9min
#
# [ 60/88] model=transformer  seed=42  horizon=48h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=83.1538  time=34.2s  total=29.5min
#
# [ 61/88] model=transformer  seed=43  horizon=24h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=92.9493  time=107.1s  total=31.3min
#
# [ 62/88] model=transformer  seed=43  horizon=48h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=75.5589  time=50.2s  total=32.1min
#
# [ 63/88] model=transformer  seed=44  horizon=24h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=101.2730  time=112.5s  total=34.0min
#
# [ 64/88] model=transformer  seed=44  horizon=48h
# ------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_neural.py:154: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
#   val_rmse=76.9014  time=40.8s  total=34.6min
#
# [ 65/88] model=nlinear  seed=42  horizon=24h
# --------------------------------------------
#   val_rmse=108.8446  time=15.3s  total=34.9min
#
# [ 66/88] model=nlinear  seed=42  horizon=48h
# --------------------------------------------
#   val_rmse=121.5400  time=14.3s  total=35.1min
#
# [ 67/88] model=nlinear  seed=43  horizon=24h
# --------------------------------------------
#   val_rmse=104.2079  time=14.8s  total=35.4min
#
# [ 68/88] model=nlinear  seed=43  horizon=48h
# --------------------------------------------
#   val_rmse=81.4516  time=44.9s  total=36.1min
#
# [ 69/88] model=nlinear  seed=44  horizon=24h
# --------------------------------------------
#   val_rmse=109.4385  time=17.0s  total=36.4min
#
# [ 70/88] model=nlinear  seed=44  horizon=48h
# --------------------------------------------
#   val_rmse=90.5205  time=34.5s  total=37.0min
#
# [ 71/88] model=dlinear  seed=42  horizon=24h
# --------------------------------------------
#   val_rmse=105.6933  time=48.8s  total=37.8min
#
# [ 72/88] model=dlinear  seed=42  horizon=48h
# --------------------------------------------
#   val_rmse=87.5675  time=48.0s  total=38.6min
#
# [ 73/88] model=dlinear  seed=43  horizon=24h
# --------------------------------------------
#   val_rmse=108.1598  time=48.1s  total=39.4min
#
# [ 74/88] model=dlinear  seed=43  horizon=48h
# --------------------------------------------
#   val_rmse=117.7169  time=15.4s  total=39.7min
#
# [ 75/88] model=dlinear  seed=44  horizon=24h
# --------------------------------------------
#   val_rmse=117.5660  time=48.4s  total=40.5min
#
# [ 76/88] model=dlinear  seed=44  horizon=48h
# --------------------------------------------
#   val_rmse=108.3875  time=24.3s  total=40.9min
#
# [ 77/88] model=patchtst  seed=42  horizon=24h
# ---------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 78/88] model=patchtst  seed=42  horizon=48h
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 79/88] model=patchtst  seed=43  horizon=24h
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 80/88] model=patchtst  seed=43  horizon=48h
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 81/88] model=patchtst  seed=44  horizon=24h
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 82/88] model=patchtst  seed=44  horizon=48h
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:126: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   ERROR running patchtst: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# [ 83/88] model=itransformer  seed=42  horizon=24h
# -------------------------------------------------
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ml-final-project/src/runner.py", line 111, in run_all
#     preds, meta = info.fn(
#                   ^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 225, in patchtst_model
#     preds, meta = _train_and_predict(build, out_fit, weather_fit, timestamps_fit, horizon, seed)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_neural.py", line 244, in _train_and_predict
#     val_pred = model(X_val_t)
#                ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ml-final-project/src/models_sota.py", line 146, in forward
#     enc = self.encoder(tokens)                             # (B*D, N, d_model)
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 540, in forward
#     output = mod(
#              ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 947, in forward
#     x = x + self._sa_block(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py", line 968, in _sa_block
#     x = self.self_attn(
#         ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 1491, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 6629, in multi_head_attention_forward
#     attn_output = scaled_dot_product_attention(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: invalid configuration argument
# Search for `cudaErrorInvalidConfiguration' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=92.6224  time=55.7s  total=45.8min
#
# [ 84/88] model=itransformer  seed=42  horizon=48h
# -------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=78.4697  time=45.1s  total=46.5min
#
# [ 85/88] model=itransformer  seed=43  horizon=24h
# -------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=94.4164  time=51.4s  total=47.4min
#
# [ 86/88] model=itransformer  seed=43  horizon=48h
# -------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=78.7511  time=34.8s  total=48.0min
#
# [ 87/88] model=itransformer  seed=44  horizon=24h
# -------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=86.4522  time=62.7s  total=49.0min
#
# [ 88/88] model=itransformer  seed=44  horizon=48h
# -------------------------------------------------
# /content/drive/MyDrive/ml-final-project/src/models_sota.py:181: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
#   val_rmse=77.2469  time=51.1s  total=49.9min
#
# [Runner] Done. completed=82 skipped=0 errors=6 total_wall=49.9min

# %% [markdown]
# ## 6. Leaderboard

# %%
import pandas as pd
pd.set_option("display.max_rows", 200)
pd.set_option("display.width", 200)

leaderboard = summarize_runs()
leaderboard
# Out:
#                  model  horizon  val_rmse_mean  val_rmse_std  val_rmse_min  val_rmse_max  n
# 0              sarimax       24        89.7449        0.0000       89.7449       89.7449  1
# 1             lightgbm       24        91.0085        0.9538       90.1589       92.0402  3
# 2         itransformer       24        91.1637        4.1777       86.4522       94.4164  3
# 3              xgboost       24        91.9135        0.8250       91.1032       92.7525  3
# 4                 lstm       24        96.4218        6.3512       89.1137      100.6063  3
# 5          transformer       24        96.7085        4.2199       92.9493      101.2730  3
# 6               bilstm       24        97.3417        1.0062       96.2548       98.2406  3
# 7            ridge_lag       24        99.4535        0.0000       99.4535       99.4535  1
# 8                 zero       24       100.3053        0.0000      100.3053      100.3053  1
# 9           linreg_lag       24       100.3184        0.0000      100.3184      100.3184  1
# 10                 tcn       24       101.7041        1.3568      100.6289      103.2285  3
# 11                 mlp       24       101.8448        4.9077       96.2280      105.3047  3
# 12                 gru       24       102.2360        1.6655      100.3138      103.2478  3
# 13     historical_mean       24       104.2867        0.0000      104.2867      104.2867  1
# 14             nlinear       24       107.4970        2.8639      104.2079      109.4385  3
# 15             dlinear       24       110.4730        6.2653      105.6933      117.5660  3
# 16  seasonal_naive_168       24       111.2700        0.0000      111.2700      111.2700  1
# 17         persistence       24       129.1698        0.0000      129.1698      129.1698  1
# 18   seasonal_naive_24       24       145.2781        0.0000      145.2781      145.2781  1
# 19             sarimax       48        68.3606        0.0000       68.3606       68.3606  1
# 20             xgboost       48        68.5899        0.3579       68.1889       68.8769  3
# 21            lightgbm       48        68.8996        0.4329       68.4028       69.1958  3
# 22                lstm       48        74.1682        1.3751       72.9823       75.6755  3
# 23           ridge_lag       48        74.7819        0.0000       74.7819       74.7819  1
# 24              bilstm       48        75.0411        7.9192       67.3766       83.1926  3
# 25                zero       48        75.3561        0.0000       75.3561       75.3561  1
# 26          linreg_lag       48        75.3764        0.0000       75.3764       75.3764  1
# 27                 tcn       48        76.9343        5.1037       72.0846       82.2589  3
# 28                 gru       48        77.7171        5.8028       73.7969       84.3832  3
# 29                 mlp       48        78.1275        1.3376       76.8116       79.4858  3
# 30        itransformer       48        78.1559        0.7997       77.2469       78.7511  3
# 31         transformer       48        78.5380        4.0533       75.5589       83.1538  3
# 32     historical_mean       48        87.7917        0.0000       87.7917       87.7917  1
# 33  seasonal_naive_168       48        89.8130        0.0000       89.8130       89.8130  1
# 34             nlinear       48        97.8374       21.0219       81.4516      121.5400  3
# 35             dlinear       48       104.5573       15.4353       87.5675      117.7169  3
# 36         persistence       48       117.7581        0.0000      117.7581      117.7581  1
# 37   seasonal_naive_24       48       123.5066        0.0000      123.5066      123.5066  1

# %%
# Leaderboard plot — use log scale on x-axis so one blown-up model
# doesn't crush everything else into invisibility, and drop any model
# whose val_rmse is more than 100× the zero baseline (clearly broken).
import matplotlib.pyplot as plt
import numpy as np

SANITY_CAP_MULT = 100   # drop any model > 100× zero-baseline RMSE
USE_LOG_X = True        # log-scale x-axis to see all models at once

fig, axes = plt.subplots(1, 2, figsize=(18, 7), sharey=False)
for ax, h in zip(axes, HORIZONS):
    sub = leaderboard[leaderboard["horizon"] == h].copy().sort_values("val_rmse_mean")
    if sub.empty:
        continue

    # Drop clearly broken runs (e.g. log-target extrapolation explosion)
    zero_rmse = sub[sub["model"] == "zero"]["val_rmse_mean"]
    if len(zero_rmse):
        cap = float(zero_rmse.iloc[0]) * SANITY_CAP_MULT
        dropped = sub[sub["val_rmse_mean"] > cap]
        if len(dropped):
            print(f"[{h}h] dropped from plot (RMSE > {cap:.0f}): "
                  + ", ".join(f"{m}={v:.3g}" for m, v in zip(dropped['model'], dropped['val_rmse_mean'])))
        sub = sub[sub["val_rmse_mean"] <= cap]

    colors = ["tab:green" if i < 3 else "steelblue" for i in range(len(sub))]
    ax.barh(sub["model"], sub["val_rmse_mean"],
            xerr=sub["val_rmse_std"], color=colors, edgecolor="white", alpha=0.85)
    ax.invert_yaxis()
    if USE_LOG_X:
        ax.set_xscale("log")
    ax.set_xlabel("Val RMSE (avg across counties, log scale)" if USE_LOG_X else "Val RMSE")
    ax.set_title(f"{h}-hour horizon", fontweight="bold")
    ax.grid(True, axis="x", alpha=0.3, which="both")

    # Annotate each bar with the numeric value
    for y, v in enumerate(sub["val_rmse_mean"]):
        ax.text(v, y, f"  {v:.2f}", va="center", fontsize=8)

fig.suptitle("Model Leaderboard — lower is better (green = top 3)",
             fontsize=14, fontweight="bold")
plt.tight_layout()
fig.savefig(config.FIGURES_DIR / "leaderboard.png", dpi=120, bbox_inches="tight")
plt.show()
print(f"Saved figure to {config.FIGURES_DIR / 'leaderboard.png'}")
# Out:
# Saved figure to /content/drive/MyDrive/ml-final-project/results_demo_split/figures/leaderboard.png

# %% [markdown]
# ## 7. Retrain best model on FULL train data and write submission CSVs
#
# The comparison above used only `train[:-48h]`. For the actual submission we want
# to retrain on the whole training set and predict the test-period timestamps.
# Picks the best model per horizon by mean val RMSE.

# %%
from src.runner import retrain_best_on_full_and_predict_test
from src.training import best_model_per_horizon

best_by_h = best_model_per_horizon()
print("Best models per horizon (by mean val RMSE):")
for h, m in best_by_h.items():
    print(f"  {h}h → {m}")

# Write one submission per horizon using its best model
for h, m in best_by_h.items():
    retrain_best_on_full_and_predict_test(m, horizon=h, seed=42)
# Out:
# Best models per horizon (by mean val RMSE):
#   24h → sarimax
#   48h → sarimax
# [Final] sarimax@24h trained on full data in 10.4s — meta={'order': [1, 0, 1], 'failed_counties': 0}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_sarimax_pred_24h.csv
# [Final] sarimax@48h trained on full data in 9.8s — meta={'order': [1, 0, 1], 'failed_counties': 0}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_sarimax_pred_48h.csv

# %% [markdown]
# ## 8. (Optional) Narrow-down sweep for top-3 models
#
# Once the broad comparison settles, uncomment and tune these cells to do a focused
# hyperparameter sweep on the top 3 architectures. Edit `MODELS_TO_RUN` above and
# crank `SEEDS` to e.g. `list(range(10))` for tighter std estimates.

# %%
# Example: only re-run the top-3 architectures on 10 seeds each for a final comparison.
# top3 = list(leaderboard.groupby("model")["val_rmse_mean"].mean().nsmallest(3).index)
# print("Focusing on:", top3)
# _ = run_all(model_names=top3, horizons=HORIZONS, seeds=list(range(10)))

# %% [markdown]
# ## 9. Generator Pre-Positioning Policy (Part II)
#
# Translate Part I predictions into the 5-county generator allocation required
# by the problem. Implements the three-tier lexicographic greedy defined in
# [`policy_methodology.md`](policy_methodology.md):
#
# | Tier | Criterion | Trigger |
# |------|-----------|---------|
# | Primary | Expected marginal household-hours `E[Δ_c(k)]` (mean across 6-run ensemble) | Always |
# | Secondary | Prediction stability `std[Δ_c(k)]` across ensemble (lower preferred) | Primary ties within 1% |
# | Tertiary | Absolute `tracked[c]` (larger preferred) | Secondary also ties within 1% |
#
# Outputs:
# * Recommendation under the **default** (risk-neutral) tier hierarchy
# * Robustness checks: 24h vs 48h, xgboost-only vs lightgbm-only, against null baselines
# * `results/submissions/recommended_counties.txt` in the PDF-specified format

# %%
# ---- Greedy allocator (mirrors policy_methodology.md §4.2 and §5.1) ----
import numpy as np

def greedy_three_tier(pred_ensemble, tracked, capacity=1000, n_gen=5, tol=0.01):
    """Three-tier lexicographic greedy.

    Primary   : argmax mean marginal coverage across the ensemble.
    Secondary : min std of marginal coverage, when Primary ties within `tol`.
    Tertiary  : argmax tracked, when Secondary also ties.

    Parameters
    ----------
    pred_ensemble : (M, L, H) ndarray
    tracked       : (L,) ndarray
    Returns (assign, trace).
    """
    pred_ensemble = np.asarray(pred_ensemble, dtype=np.float64)
    tracked = np.asarray(tracked, dtype=np.float64)
    M, L, H = pred_ensemble.shape
    assert tracked.shape == (L,)

    assign = np.zeros(L, dtype=int)
    trace = []
    for step in range(n_gen):
        k_arr = assign[None, :, None]
        cov_now  = np.minimum(k_arr       * capacity, pred_ensemble).sum(axis=2)
        cov_next = np.minimum((k_arr + 1) * capacity, pred_ensemble).sum(axis=2)
        gains = cov_next - cov_now
        gain_mean = gains.mean(axis=0)
        gain_std  = gains.std(axis=0)

        top = gain_mean.max()
        tied_1 = np.where(gain_mean >= top * (1 - tol) - 1e-9)[0]
        if len(tied_1) == 1:
            best = int(tied_1[0]); tier = "primary"
        else:
            stds = gain_std[tied_1]
            min_std = stds.min()
            tied_2 = tied_1[stds <= min_std * (1 + tol) + 1e-9]
            if len(tied_2) == 1:
                best = int(tied_2[0]); tier = "secondary"
            else:
                best = int(tied_2[np.argmax(tracked[tied_2])]); tier = "tertiary"

        assign[best] += 1
        trace.append({
            "step": step + 1, "county_idx": best,
            "gain_mean": float(gain_mean[best]),
            "gain_std":  float(gain_std[best]),
            "tracked":   float(tracked[best]),
            "n_candidates_primary": len(tied_1),
            "tier_used": tier,
        })
    return assign, trace


def allocation_to_fips(assign, locations):
    return [locations[li] for li, k in enumerate(assign) for _ in range(int(k))]


def print_trace(trace, locations):
    for t in trace:
        print(f"  gen #{t['step']} -> {locations[t['county_idx']]}  "
              f"[tier={t['tier_used']}, n_prim_ties={t['n_candidates_primary']}]  "
              f"gain = {t['gain_mean']:>8,.0f} \u00b1 {t['gain_std']:>6,.0f}  "
              f"tracked = {t['tracked']:>9,.0f}")

# %%
# ---- Build ensemble of test predictions (3 seeds x 2 model families = 6) ----
# Each call retrains the model on the FULL training set (not just val-fit),
# then predicts the test-period timestamps. Total time ~3 min on A100.
import numpy as np
import xarray as xr
from src.runner import retrain_best_on_full_and_predict_test

ENSEMBLE_MODELS = ["xgboost", "lightgbm", "two_stage_lgb"]  # 3 families × 3 seeds = 9 predictions for Primary/Secondary
ENSEMBLE_SEEDS  = [42, 43, 44]

ensemble = {}
for h in HORIZONS:
    stack = []
    for model in ENSEMBLE_MODELS:
        for seed in ENSEMBLE_SEEDS:
            preds = retrain_best_on_full_and_predict_test(model, horizon=h, seed=seed)
            stack.append(preds.T)  # (H, L) -> (L, H)
    ensemble[h] = np.stack(stack)  # (M, L, H)
    print(f"Horizon {h}h: ensemble shape = {ensemble[h].shape}")

# Tracked (tertiary signal) — time-mean since tracked is slowly varying.
ds_train_for_tracked = xr.open_dataset(config.TRAIN_PATH)
locations = [str(x) for x in ds_train_for_tracked.location.values]
tracked = ds_train_for_tracked.tracked.mean(dim="timestamp").values.astype(float)
print(f"tracked shape = {tracked.shape},  min = {tracked.min():.0f},  max = {tracked.max():.0f}")
# Out:
# [Final] xgboost@24h trained on full data in 17.5s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_24h.csv
# [Final] xgboost@24h trained on full data in 17.5s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_24h.csv
# [Final] xgboost@24h trained on full data in 17.4s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_24h.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [Final] lightgbm@24h trained on full data in 43.1s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_24h.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [Final] lightgbm@24h trained on full data in 41.6s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_24h.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [Final] lightgbm@24h trained on full data in 43.7s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_24h.csv
# Horizon 24h: ensemble shape = (6, 83, 24)
# [Final] xgboost@48h trained on full data in 30.7s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_48h.csv
# [Final] xgboost@48h trained on full data in 31.0s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_48h.csv
# [Final] xgboost@48h trained on full data in 30.9s — meta={'n_estimators': 500, 'max_depth': 6, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_xgboost_pred_48h.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [Final] lightgbm@48h trained on full data in 79.8s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_48h.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [Final] lightgbm@48h trained on full data in 76.7s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_48h.csv
# [Final] lightgbm@48h trained on full data in 84.0s — meta={'n_estimators': 800, 'num_leaves': 63, 'lr': 0.05, 'log_target': True, 'origin_stride': 4}
# [Final] wrote submission → /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/final_lightgbm_pred_48h.csv
# Horizon 48h: ensemble shape = (6, 83, 48)
# tracked shape = (83,),  min = 2122,  max = 922425
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
# ---- Primary recommendation: 48h horizon, full 6-model ensemble ----
PRIMARY_HORIZON = 48
pred_ensemble = ensemble[PRIMARY_HORIZON]

assign, trace = greedy_three_tier(
    pred_ensemble=pred_ensemble,
    tracked=tracked,
    capacity=1000, n_gen=5, tol=0.01,
)

print(f"=== Primary recommendation ({PRIMARY_HORIZON}h horizon, full ensemble) ===")
print_trace(trace, locations)
fips_final = allocation_to_fips(assign, locations)
total_exp  = sum(t["gain_mean"] for t in trace)
print(f"\nRecommended counties: {fips_final}")
print(f"Expected total household-hours served: {total_exp:,.0f}")
# Out:
# === Primary recommendation (48h horizon, full ensemble) ===
#   gen #1 -> 26163  [tier=primary, n_prim_ties=1]  gain =   34,059 ±  6,242  tracked =   922,425
#   gen #2 -> 26125  [tier=primary, n_prim_ties=1]  gain =   20,535 ±  3,565  tracked =   618,067
#   gen #3 -> 26161  [tier=primary, n_prim_ties=1]  gain =    4,079 ±  1,027  tracked =   174,443
#   gen #4 -> 26099  [tier=primary, n_prim_ties=1]  gain =    3,450 ±    428  tracked =   413,676
#   gen #5 -> 26163  [tier=primary, n_prim_ties=1]  gain =    2,349 ±  3,881  tracked =   922,425
#
# Recommended counties: ['26099', '26125', '26161', '26163', '26163']
# Expected total household-hours served: 64,472

# %%
# ---- Robustness: run the allocator under variant configurations ----
import pandas as pd

configs = {
    "default_48h_full_ensemble": (ensemble[48], tracked),
    "24h_horizon_full_ensemble": (ensemble[24], tracked),
    "48h_xgboost_only":          (ensemble[48][:len(ENSEMBLE_SEEDS)], tracked),
    "48h_lightgbm_only":         (ensemble[48][len(ENSEMBLE_SEEDS):], tracked),
}

rows = []
all_picks = {}
for name, (pe, tr) in configs.items():
    a, _t = greedy_three_tier(pe, tr, capacity=1000, n_gen=5, tol=0.01)
    picks = allocation_to_fips(a, locations)
    all_picks[name] = picks
    rows.append({"config": name, "recommendation": picks,
                 "n_unique_counties": len(set(picks))})
robust_df = pd.DataFrame(rows)
print("=== Robustness table ===")
print(robust_df.to_string(index=False))

# Overlap matrix: how many counties do any two configs share (with multiplicity)?
print("\n=== Pairwise overlap (count of shared FIPS slots, max 5) ===")
names = list(all_picks.keys())
M = pd.DataFrame(index=names, columns=names, dtype=int)
for a in names:
    for b in names:
        # Use Counter-style intersection to respect multiplicity.
        from collections import Counter
        ca, cb = Counter(all_picks[a]), Counter(all_picks[b])
        M.loc[a, b] = sum((ca & cb).values())
print(M.to_string())
# Out:
# === Robustness table ===
#                    config                      recommendation  n_unique_counties
# default_48h_full_ensemble [26099, 26125, 26161, 26163, 26163]                  4
# 24h_horizon_full_ensemble [26099, 26123, 26125, 26163, 26163]                  4
#          48h_xgboost_only [26099, 26125, 26161, 26163, 26163]                  4
#         48h_lightgbm_only [26081, 26099, 26125, 26161, 26163]                  5
#
# === Pairwise overlap (count of shared FIPS slots, max 5) ===
#                            default_48h_full_ensemble  24h_horizon_full_ensemble  48h_xgboost_only  48h_lightgbm_only
# default_48h_full_ensemble                        5.0                        4.0               5.0                4.0
# 24h_horizon_full_ensemble                        4.0                        5.0               4.0                3.0
# 48h_xgboost_only                                 5.0                        4.0               5.0                4.0
# 48h_lightgbm_only                                4.0                        3.0               4.0                5.0

# %%
# ---- Null-policy comparisons (report-defensive baselines) ----
# Does our prediction-driven policy actually beat simple heuristics on the val split?
from collections import Counter

# Use val-period ground truth (last 48h of train) as the evaluation window
ds_val_trust = xr.open_dataset(config.TRAIN_PATH)
out_val = ds_val_trust.out.transpose("location", "timestamp").values[:, -PRIMARY_HORIZON:]  # (L, H)

def total_served(fips_list, truth_window):
    """Given a list of FIPS assignments and (L, H) ground truth, return hh-hours served."""
    cnt = Counter(fips_list)
    total = 0.0
    for fips, k in cnt.items():
        li = locations.index(fips)
        total += np.minimum(k * 1000, truth_window[li]).sum()
    return float(total)

# Three baseline policies:
hist_total = ds_val_trust.out.transpose("location", "timestamp").values.sum(axis=1)

policies = {
    "our_policy (pred-driven, 3-tier)": fips_final,
    "population-only (top-5 tracked)":   [locations[i] for i in np.argsort(-tracked)[:5]],
    "historical-only (top-5 hist total)":[locations[i] for i in np.argsort(-hist_total)[:5]],
    "random-sample":                     list(np.random.RandomState(42).choice(locations, 5, replace=False)),
}

print("=== Policy comparison on val-window ground truth ===")
print(f"{'policy':40s}  {'hh-hours served':>15s}  recommendation")
for name, picks in policies.items():
    served = total_served(picks, out_val)
    print(f"{name:40s}  {served:>15,.0f}  {picks}")
# Out:
# === Policy comparison on val-window ground truth ===
# policy                                    hh-hours served  recommendation
# our_policy (pred-driven, 3-tier)                   79,400  ['26099', '26125', '26161', '26163', '26163']
# population-only (top-5 tracked)                    61,865  ['26163', '26125', '26099', '26081', '26049']
# historical-only (top-5 hist total)                 65,566  ['26125', '26163', '26099', '26161', '26081']
# random-sample                                       3,960  [np.str_('26061'), np.str_('26001'), np.str_('26045'), np.str_('26063'), np.str_('26037')]

# %%
# ---- Write the recommended_counties.txt submission file ----
submission_path = config.SUBMISSIONS_DIR / "recommended_counties.txt"
with open(submission_path, "w") as f:
    f.write(f"[{', '.join(fips_final)}]\n")
print(f"Wrote {submission_path}")
print(f"Contents: [{', '.join(fips_final)}]")
# Out:
# Wrote /content/drive/MyDrive/ml-final-project/results_demo_split/submissions/recommended_counties.txt
# Contents: [26099, 26125, 26161, 26163, 26163]

# %% [markdown]
# ## 10. Auto-release the Colab runtime (stop burning A100 credits)
#
# Once everything above finishes, this cell releases the GPU so you stop paying for idle compute while asleep.
#
# * **60-second grace countdown** first — interrupt the cell (■ / `Ctrl-M I`) to cancel if you're still iterating.
# * Uses the official [`google.colab.runtime.unassign()`](https://colab.research.google.com/notebooks/pro.ipynb) — disconnects **and** releases the runtime (which is what frees your Colab Pro compute units). `!kill -9 -1` only disconnects; the runtime can keep billing until its idle timeout.
# * Set `AUTO_SHUTDOWN = False` if you want to keep the session after completion.
#
# > Run this cell with **Run All**, not manually. If you Run All from the top, the countdown only fires after all upstream experiments finish.

# %%
AUTO_SHUTDOWN = True
GRACE_SECONDS = 60
# Where to copy results/ before shutdown (only used if project isn't already in Drive).
# Change this if you want a different Drive location.
DRIVE_BACKUP_PARENT = "/content/drive/MyDrive"

# ---- 1. Final sanity print ----
try:
    from src.training import summarize_runs
    print("=== Final leaderboard ===")
    print(summarize_runs().to_string(index=False))
    print()
    print("Saved under results/:")
    for p in sorted(config.RESULTS_DIR.rglob("*")):
        if p.is_file():
            sz = p.stat().st_size
            print(f"  {p.relative_to(config.RESULTS_DIR)}  ({sz/1024:.1f} KB)")
except Exception as e:
    print(f"summary failed: {e}")

# ---- 2. Back up results to Drive if the project lives on the ephemeral VM ----
IS_COLAB = "google.colab" in sys.modules
project_on_drive = str(PROJECT_ROOT).startswith("/content/drive/")
backup_dest = None
if IS_COLAB and not project_on_drive:
    import shutil, datetime
    # Ensure Drive is mounted
    if not Path("/content/drive").exists():
        from google.colab import drive as _drive
        _drive.mount("/content/drive")
    stamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    backup_dest = Path(DRIVE_BACKUP_PARENT) / f"ml-final-project-results_{stamp}"
    print(f"\nCopying results/ → {backup_dest} (so they survive shutdown)...")
    shutil.copytree(config.RESULTS_DIR, backup_dest)
    print(f"✓ Backup complete: {backup_dest}")
elif IS_COLAB and project_on_drive:
    print(f"\nProject already lives under Drive ({PROJECT_ROOT}) — results/ is persistent, no backup needed.")

# ---- 3. Shutdown with grace period ----
if AUTO_SHUTDOWN and IS_COLAB:
    import time
    print()
    for i in range(GRACE_SECONDS, 0, -1):
        print(f"\rShutting down in {i:3d}s ... interrupt this cell to cancel.", end="", flush=True)
        time.sleep(1)
    print()
    if backup_dest is not None:
        print(f"Results backed up at: {backup_dest}")
    print("Releasing runtime via google.colab.runtime.unassign() ...")
    from google.colab import runtime
    runtime.unassign()
else:
    print("\nAuto-shutdown skipped (not in Colab, or AUTO_SHUTDOWN=False).")
# Out:
# === Final leaderboard ===
#              model  horizon  val_rmse_mean  val_rmse_std  val_rmse_min  val_rmse_max  n
#            sarimax       24        89.7449        0.0000       89.7449       89.7449  1
#           lightgbm       24        91.0085        0.9538       90.1589       92.0402  3
#       itransformer       24        91.1637        4.1777       86.4522       94.4164  3
#            xgboost       24        91.9135        0.8250       91.1032       92.7525  3
#               lstm       24        96.4218        6.3512       89.1137      100.6063  3
#        transformer       24        96.7085        4.2199       92.9493      101.2730  3
#             bilstm       24        97.3417        1.0062       96.2548       98.2406  3
#          ridge_lag       24        99.4535        0.0000       99.4535       99.4535  1
#               zero       24       100.3053        0.0000      100.3053      100.3053  1
#         linreg_lag       24       100.3184        0.0000      100.3184      100.3184  1
#                tcn       24       101.7041        1.3568      100.6289      103.2285  3
#                mlp       24       101.8448        4.9077       96.2280      105.3047  3
#                gru       24       102.2360        1.6655      100.3138      103.2478  3
#    historical_mean       24       104.2867        0.0000      104.2867      104.2867  1
#            nlinear       24       107.4970        2.8639      104.2079      109.4385  3
#            dlinear       24       110.4730        6.2653      105.6933      117.5660  3
# seasonal_naive_168       24       111.2700        0.0000      111.2700      111.2700  1
#        persistence       24       129.1698        0.0000      129.1698      129.1698  1
#  seasonal_naive_24       24       145.2781        0.0000      145.2781      145.2781  1
#            sarimax       48        68.3606        0.0000       68.3606       68.3606  1
#            xgboost       48        68.5899        0.3579       68.1889       68.8769  3
#           lightgbm       48        68.8996        0.4329       68.4028       69.1958  3
#               lstm       48        74.1682        1.3751       72.9823       75.6755  3
#          ridge_lag       48        74.7819        0.0000       74.7819       74.7819  1
#             bilstm       48        75.0411        7.9192       67.3766       83.1926  3
#               zero       48        75.3561        0.0000       75.3561       75.3561  1
#         linreg_lag       48        75.3764        0.0000       75.3764       75.3764  1
#                tcn       48        76.9343        5.1037       72.0846       82.2589  3
#                gru       48        77.7171        5.8028       73.7969       84.3832  3
#                mlp       48        78.1275        1.3376       76.8116       79.4858  3
#       itransformer       48        78.1559        0.7997       77.2469       78.7511  3
#        transformer       48        78.5380        4.0533       75.5589       83.1538  3
#    historical_mean       48        87.7917        0.0000       87.7917       87.7917  1
# seasonal_naive_168       48        89.8130        0.0000       89.8130       89.8130  1
#            nlinear       48        97.8374       21.0219       81.4516      121.5400  3
#            dlinear       48       104.5573       15.4353       87.5675      117.7169  3
#        persistence       48       117.7581        0.0000      117.7581      117.7581  1
#  seasonal_naive_24       48       123.5066        0.0000      123.5066      123.5066  1
#
# Saved under results/:
#   experiment_runs.csv  (13.3 KB)
#   figures/leaderboard.png  (118.2 KB)
#   submissions/final_lightgbm_pred_24h.csv  (86.3 KB)
#   submissions/final_lightgbm_pred_48h.csv  (172.6 KB)
#   submissions/final_sarimax_pred_24h.csv  (77.1 KB)
#   submissions/final_sarimax_pred_48h.csv  (154.9 KB)
#   submissions/final_xgboost_pred_24h.csv  (85.7 KB)
#   submissions/final_xgboost_pred_48h.csv  (170.8 KB)
#   submissions/recommended_counties.txt  (0.0 KB)
#   val_preds/bilstm__seed42__h24.npy  (7.9 KB)
#   val_preds/bilstm__seed42__h48.npy  (15.7 KB)
#   val_preds/bilstm__seed43__h24.npy  (7.9 KB)
#   val_preds/bilstm__seed43__h48.npy  (15.7 KB)
#   val_preds/bilstm__seed44__h24.npy  (7.9 KB)
#   val_preds/bilstm__seed44__h48.npy  (15.7 KB)
#   val_preds/dlinear__seed42__h24.npy  (7.9 KB)
#   val_preds/dlinear__seed42__h48.npy  (15.7 KB)
#   val_preds/dlinear__seed43__h24.npy  (7.9 KB)
#   val_preds/dlinear__seed43__h48.npy  (15.7 KB)
#   val_preds/dlinear__seed44__h24.npy  (7.9 KB)
#   val_preds/dlinear__seed44__h48.npy  (15.7 KB)
#   val_preds/gru__seed42__h24.npy  (7.9 KB)
#   val_preds/gru__seed42__h48.npy  (15.7 KB)
#   val_preds/gru__seed43__h24.npy  (7.9 KB)
#   val_preds/gru__seed43__h48.npy  (15.7 KB)
#   val_preds/gru__seed44__h24.npy  (7.9 KB)
#   val_preds/gru__seed44__h48.npy  (15.7 KB)
#   val_preds/historical_mean__seed42__h24.npy  (7.9 KB)
#   val_preds/historical_mean__seed42__h48.npy  (15.7 KB)
#   val_preds/itransformer__seed42__h24.npy  (7.9 KB)
#   val_preds/itransformer__seed42__h48.npy  (15.7 KB)
#   val_preds/itransformer__seed43__h24.npy  (7.9 KB)
#   val_preds/itransformer__seed43__h48.npy  (15.7 KB)
#   val_preds/itransformer__seed44__h24.npy  (7.9 KB)
#   val_preds/itransformer__seed44__h48.npy  (15.7 KB)
#   val_preds/lightgbm__seed42__h24.npy  (7.9 KB)
#   val_preds/lightgbm__seed42__h48.npy  (15.7 KB)
#   val_preds/lightgbm__seed43__h24.npy  (7.9 KB)
#   val_preds/lightgbm__seed43__h48.npy  (15.7 KB)
#   val_preds/lightgbm__seed44__h24.npy  (7.9 KB)
#   val_preds/lightgbm__seed44__h48.npy  (15.7 KB)
#   val_preds/linreg_lag__seed42__h24.npy  (7.9 KB)
#   val_preds/linreg_lag__seed42__h48.npy  (15.7 KB)
#   val_preds/lstm__seed42__h24.npy  (7.9 KB)
#   val_preds/lstm__seed42__h48.npy  (15.7 KB)
#   val_preds/lstm__seed43__h24.npy  (7.9 KB)
#   val_preds/lstm__seed43__h48.npy  (15.7 KB)
#   val_preds/lstm__seed44__h24.npy  (7.9 KB)
#   val_preds/lstm__seed44__h48.npy  (15.7 KB)
#   val_preds/mlp__seed42__h24.npy  (7.9 KB)
#   val_preds/mlp__seed42__h48.npy  (15.7 KB)
#   val_preds/mlp__seed43__h24.npy  (7.9 KB)
#   val_preds/mlp__seed43__h48.npy  (15.7 KB)
#   val_preds/mlp__seed44__h24.npy  (7.9 KB)
#   val_preds/mlp__seed44__h48.npy  (15.7 KB)
#   val_preds/nlinear__seed42__h24.npy  (7.9 KB)
#   val_preds/nlinear__seed42__h48.npy  (15.7 KB)
#   val_preds/nlinear__seed43__h24.npy  (7.9 KB)
#   val_preds/nlinear__seed43__h48.npy  (15.7 KB)
#   val_preds/nlinear__seed44__h24.npy  (7.9 KB)
#   val_preds/nlinear__seed44__h48.npy  (15.7 KB)
#   val_preds/persistence__seed42__h24.npy  (7.9 KB)
#   val_preds/persistence__seed42__h48.npy  (15.7 KB)
#   val_preds/ridge_lag__seed42__h24.npy  (7.9 KB)
#   val_preds/ridge_lag__seed42__h48.npy  (15.7 KB)
#   val_preds/sarimax__seed42__h24.npy  (7.9 KB)
#   val_preds/sarimax__seed42__h48.npy  (15.7 KB)
#   val_preds/seasonal_naive_168__seed42__h24.npy  (7.9 KB)
#   val_preds/seasonal_naive_168__seed42__h48.npy  (15.7 KB)
#   val_preds/seasonal_naive_24__seed42__h24.npy  (7.9 KB)
#   val_preds/seasonal_naive_24__seed42__h48.npy  (15.7 KB)
#   val_preds/tcn__seed42__h24.npy  (7.9 KB)
#   val_preds/tcn__seed42__h48.npy  (15.7 KB)
#   val_preds/tcn__seed43__h24.npy  (7.9 KB)
#   val_preds/tcn__seed43__h48.npy  (15.7 KB)
#   val_preds/tcn__seed44__h24.npy  (7.9 KB)
#   val_preds/tcn__seed44__h48.npy  (15.7 KB)
#   val_preds/transformer__seed42__h24.npy  (7.9 KB)
#   val_preds/transformer__seed42__h48.npy  (15.7 KB)
#   val_preds/transformer__seed43__h24.npy  (7.9 KB)
#   val_preds/transformer__seed43__h48.npy  (15.7 KB)
#   val_preds/transformer__seed44__h24.npy  (7.9 KB)
#   val_preds/transformer__seed44__h48.npy  (15.7 KB)
#   val_preds/xgboost__seed42__h24.npy  (7.9 KB)
#   val_preds/xgboost__seed42__h48.npy  (15.7 KB)
#   val_preds/xgboost__seed43__h24.npy  (7.9 KB)
#   val_preds/xgboost__seed43__h48.npy  (15.7 KB)
#   val_preds/xgboost__seed44__h24.npy  (7.9 KB)
#   val_preds/xgboost__seed44__h48.npy  (15.7 KB)
#   val_preds/zero__seed42__h24.npy  (7.9 KB)
#   val_preds/zero__seed42__h48.npy  (15.7 KB)
#
# Project already lives under Drive (/content/drive/MyDrive/ml-final-project) — results/ is persistent, no backup needed.
#
# Shutting down in   1s ... interrupt this cell to cancel.
# Releasing runtime via google.colab.runtime.unassign() ...
